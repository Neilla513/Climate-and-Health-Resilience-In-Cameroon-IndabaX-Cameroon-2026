# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import re, os

# %%
data = pd.read_excel("Dataset_complet_Meteo.xlsx")

# %%
data.head()
# Out:
#    id       time  weather_code   temperature_2m_max   temperature_2m_min  \
# 0   1 2020-01-01             3                 33.2  2026-09-21 00:00:00
# 1   2 2020-01-02             3                 31.9  2026-09-21 00:00:00
# 2   3 2020-01-03             3                 32.0  2026-03-19 00:00:00
# 3   4 2020-01-04             3  2026-05-31 00:00:00  2026-01-19 00:00:00
# 4   5 2020-01-05             3                 31.9  2026-03-19 00:00:00
#
#    temperature_2m_mean apparent_temperature_max apparent_temperature_min  \
# 0  2026-05-26 00:00:00                     34.0      2026-06-25 00:00:00
# 1  2026-09-25 00:00:00      2026-01-31 00:00:00      2026-03-23 00:00:00
# 2                 25.0      2026-07-31 00:00:00      2026-02-19 00:00:00
# 3  2026-07-24 00:00:00                     32.3      2026-07-20 00:00:00
# 4  2026-08-24 00:00:00                     33.1      2026-03-20 00:00:00
#
#   apparent_temperature_mean             sunrise  ... precipitation_hours  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87240 entries, 0 to 87239
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           87240 non-null  int64
#  1   time                         87240 non-null  datetime64[ns]
#  2   weather_code                 87240 non-null  int64
#  3   temperature_2m_max           87240 non-null  object
#  4   temperature_2m_min           87240 non-null  object
#  5   temperature_2m_mean          87240 non-null  object
#  6   apparent_temperature_max     87240 non-null  object
#  7   apparent_temperature_min     87240 non-null  object
#  8   apparent_temperature_mean    87240 non-null  object
#  9   sunrise                      87240 non-null  datetime64[ns]
#  10  sunset                       87240 non-null  datetime64[ns]
#  11  daylight_duration            87240 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 id                           time  weather_code  \
# count  87240.00000                          87240  87240.000000
# mean    2617.70000  2022-12-26 00:00:00.000000256     40.556385
# min        1.00000            2020-01-01 00:00:00      0.000000
# 25%     1148.00000            2021-06-29 00:00:00      3.000000
# 50%     2318.00000            2022-12-26 00:00:00     51.000000
# 75%     3681.00000            2024-06-23 00:00:00     61.000000
# max     8724.00000            2025-12-20 00:00:00     65.000000
# std     1880.39875                            NaN     25.739631
#
#                              sunrise                         sunset  \
# count                          87240                          87240
# mean   2022-12-26 06:08:23.672626944  2022-12-26 18:15:49.028885760
# min              2020-01-01 06:05:00            2020-01-01 17:45:00
# 25%              2021-06-29 05:52:45            2021-06-29 18:25:45
# ...

# %%
data.columns
# Out:
# Index(['id', 'time', 'weather_code', 'temperature_2m_max',
#        'temperature_2m_min', 'temperature_2m_mean', 'apparent_temperature_max',
#        'apparent_temperature_min', 'apparent_temperature_mean', 'sunrise',
#        'sunset', 'daylight_duration', 'sunshine_duration', 'precipitation_sum',
#        'rain_sum', 'snowfall_sum', 'precipitation_hours', 'wind_speed_10m_max',
#        'wind_gusts_10m_max', 'wind_direction_10m_dominant',
#        'shortwave_radiation_sum', 'et0_fao_evapotranspiration', 'city',
#        'region', 'latitude', 'longitude'],
#       dtype='object')

# %%
data["id"].nunique()
# Out:
# 8724

# %%
data.shape
# Out:
# (87240, 26)

# %%
data.isnull().sum()
# Out:
# id                             0
# time                           0
# weather_code                   0
# temperature_2m_max             0
# temperature_2m_min             0
# temperature_2m_mean            0
# apparent_temperature_max       0
# apparent_temperature_min       0
# apparent_temperature_mean      0
# sunrise                        0
# sunset                         0
# daylight_duration              0
# sunshine_duration              0
# precipitation_sum              0
# rain_sum                       0
# snowfall_sum                   0
# precipitation_hours            0
# wind_speed_10m_max             0
# wind_gusts_10m_max             0
# wind_direction_10m_dominant    0
# shortwave_radiation_sum        0
# et0_fao_evapotranspiration     0
# city                           0
# region                         0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
data["time"].max(), data["time"].mean(), data["time"].min()
# Out:
# (Timestamp('2025-12-20 00:00:00'),
#  Timestamp('2022-12-26 00:00:00.000000256'),
#  Timestamp('2020-01-01 00:00:00'))

# %%
data["time"].nunique()
# Out:
# 2181

# %%
data["time"].value_counts()
# Out:
# time
# 2020-01-01    40
# 2020-01-02    40
# 2020-01-03    40
# 2020-01-04    40
# 2020-01-05    40
#               ..
# 2025-12-16    40
# 2025-12-17    40
# 2025-12-18    40
# 2025-12-19    40
# 2025-12-20    40
# Name: count, Length: 2181, dtype: int64

# %%
data["time"].value_counts().to_excel("temps.xlsx")

# %%
data.columns
# Out:
# Index(['id', 'time', 'weather_code', 'temperature_2m_max',
#        'temperature_2m_min', 'temperature_2m_mean', 'apparent_temperature_max',
#        'apparent_temperature_min', 'apparent_temperature_mean', 'sunrise',
#        'sunset', 'daylight_duration', 'sunshine_duration', 'precipitation_sum',
#        'rain_sum', 'snowfall_sum', 'precipitation_hours', 'wind_speed_10m_max',
#        'wind_gusts_10m_max', 'wind_direction_10m_dominant',
#        'shortwave_radiation_sum', 'et0_fao_evapotranspiration', 'city',
#        'region', 'latitude', 'longitude'],
#       dtype='object')

# %%
data['sunset'].nunique()
# Out:
# 46448

# %%
data['latitude'].nunique()
# Out:
# 39

# %%
data['longitude'].nunique()
# Out:
# 39
